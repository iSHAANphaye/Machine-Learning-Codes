# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

# %%
data = 2*np.random.random((10,10))
data2 = 3*np.random.random((10,10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image = mpimg.imread(r'C:\Users\ishaan phaye\Pictures\No Mans Sky\Mar-15@0.18.23.png')
plt.imshow(image)
plt.show()

# %% [markdown]
# CREATE PLOT ( FIGURE AND AXES )

# %%
fig = plt.figure()
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %%
fig.add_axes([10,10,10,10])
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
fig3, axes = plt.subplots(nrows=1,ncols=2)
fig4, axes2 = plt.subplots(ncols=3)

# %% [markdown]
# SAVE PLOT

# %%
plt.savefig('plot1.png')
plt.savefig('plot2.png', transparent=True)

# %%
data = 2*np.random.random((10,10))
data2 = 3*np.random.random((10,10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image = mpimg.imread(r'C:\Users\ishaan phaye\Pictures\No Mans Sky\Mar-15@0.18.23.png')
plt.imshow(image)

# %%
print(image.shape)
# Out:
# (1080, 1920, 3)

# %%
imgcrop=image[0:1080, 0:1200, 0:3]
plt.imshow(imgcrop)
